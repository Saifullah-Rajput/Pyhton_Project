# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot([0, 1, 2, 3, 4, 5])

plt.show()

# %%
sns.displot([0, 1, 2, 3, 4, 5], kind="kde")

plt.show()

# %%
from numpy import random

x = random.normal(size=(2, 3))

print(x)
# sns.x // Error
# plt.show() // Error
# Out:
# [[-0.3617476   0.90093701  0.72273414]
#  [-1.42708857  1.6340206   0.56068384]]

# %%
from numpy import random

x = random.normal(loc=1, scale=1, size=(2, 3))

print(x)
# Out:
# [[ 0.18923612  1.19525657  1.03292407]
#  [-0.58103772  0.94304518  0.92359154]]

# %%
sns.displot(random.normal(size=2000), kind="kde")

plt.show()
